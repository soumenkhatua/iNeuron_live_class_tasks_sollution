# %%
#Task 2 - Superstore_USA
1 . Load this data in sql and in pandas with a relation in sql 
2 . While loading this data you dont have to create a table manually. You can use any automated approach to create a table and load a data in bulk in table 
3 . Find out how return that we ahve recived and with a product id 
4 . try  to join order and return data both in sql and pandas 
5 . Try to find out how many unique customer that we have 
6 . try to find out in how many regions we are selling a product and who is a manager for a respective region 
7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
9 . base on question number 8 find out for which order id we have shipment duration more than 10 days 
10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
11 . Gorup by region and find out which region is more profitable 
12 . Try to find out overalll in which country we are giving more didscount 
13 . Give me a list of unique postal code 
14 . which customer segement is more profitalble find it out . 
15 . try to find out the 10th most loss making product catagory . 
16 . Try to find out 10 top  product with highest margins

# %%
import pandas as pd
from sqlalchemy import engine as sa
import xlrd

# %%
Superstore = pd.read_excel(r"C:\Users\soume\data fsds\Superstore_USA.xlsx")

# %%
Superstore
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#        Region State or Province        City  Postal Code Order Date  \
# 0     Central          Illinois     Addison        60101 2012-05-28
# 1        West        Washington   Anacortes        98221 2010-07-07
# 2        West        Washington   Anacortes        98221 2011-07-27
# 3        West        Washington   Anacortes        98221 2011-07-27
# 4        West        Washington   Anacortes        98221 2011-07-27
# ...       ...               ...         ...          ...        ...
# 9421     East     West Virginia  Charleston        25314 2013-05-14
# 9422     East     West Virginia  Charleston        25314 2013-05-14
# 9423     East     West Virginia  Charleston        25314 2013-09-12
# 9424     West           Wyoming    Cheyenne        82001 2010-02-08
# 9425     West           Wyoming    Cheyenne        82001 2013-09-12
#
#       Ship Date       Profit  Quantity ordered new    Sales Order ID
# 0    2012-05-30     1.320000                     2     5.90    88525
# 1    2010-07-08     4.560000                     4    13.01    88522
# 2    2011-07-28   -47.640000                     7    49.92    88523
# 3    2011-07-28   -30.510000                     7    41.64    88523
# 4    2011-07-27   998.202300                     8  1446.67    88523
# ...         ...          ...                   ...      ...      ...
# 9421 2013-05-15   137.860000                    13   447.87    87532
# 9422 2013-05-14   -39.070000                     3    13.23    87532
# 9423 2013-09-14 -1225.029097                     4  2215.93    87533
# 9424 2010-02-11   349.485000                     5   506.50    87530
# 9425 2013-09-14    78.062400                    23   172.48    87533
#
# [9426 rows x 24 columns]

# %%
Superstore1 = pd.read_excel(r"C:\Users\soume\data fsds\Superstore_USA.xlsx","Returns",names = ['Order ID','Status'])
Superstore1
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
Superstore2 = pd.read_excel(r"C:\Users\soume\data fsds\Superstore_USA.xlsx","Users")
Superstore2
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
Superstore
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#        Region State or Province        City  Postal Code Order Date  \
# 0     Central          Illinois     Addison        60101 2012-05-28
# 1        West        Washington   Anacortes        98221 2010-07-07
# 2        West        Washington   Anacortes        98221 2011-07-27
# 3        West        Washington   Anacortes        98221 2011-07-27
# 4        West        Washington   Anacortes        98221 2011-07-27
# ...       ...               ...         ...          ...        ...
# 9421     East     West Virginia  Charleston        25314 2013-05-14
# 9422     East     West Virginia  Charleston        25314 2013-05-14
# 9423     East     West Virginia  Charleston        25314 2013-09-12
# 9424     West           Wyoming    Cheyenne        82001 2010-02-08
# 9425     West           Wyoming    Cheyenne        82001 2013-09-12
#
#       Ship Date       Profit  Quantity ordered new    Sales Order ID
# 0    2012-05-30     1.320000                     2     5.90    88525
# 1    2010-07-08     4.560000                     4    13.01    88522
# 2    2011-07-28   -47.640000                     7    49.92    88523
# 3    2011-07-28   -30.510000                     7    41.64    88523
# 4    2011-07-27   998.202300                     8  1446.67    88523
# ...         ...          ...                   ...      ...      ...
# 9421 2013-05-15   137.860000                    13   447.87    87532
# 9422 2013-05-14   -39.070000                     3    13.23    87532
# 9423 2013-09-14 -1225.029097                     4  2215.93    87533
# 9424 2010-02-11   349.485000                     5   506.50    87530
# 9425 2013-09-14    78.062400                    23   172.48    87533
#
# [9426 rows x 24 columns]

# %%
Superstore1
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
Superstore2
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
# Connect to MySQL
import mysql.connector as conn

mydb = conn.connect(host ="localhost" , user = "root" , passwd = "soumen123khatua")
cursor = mydb.cursor()
cursor.execute("create database if not exists USA_Data")

# %%
# Read this dataset in MySQL
engine = sa.create_engine('mysql+pymysql://root:soumen123khatua@localhost/USA_Data')

# %%
Superstore.to_sql("USA_data1" , con = engine)
#"USA_data1" is a table inside of "USA_DAta" table

# %%
cursor.execute("use USA_Data")

# %%
data = pd.read_sql_query("select * from USA_Data1 ",engine)
data
# Out:
#       index  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0         0   18606  Not Specified      0.01        2.88           0.50
# 1         1   20847           High      0.01        2.84           0.93
# 2         2   23086  Not Specified      0.03        6.68           6.15
# 3         3   23087  Not Specified      0.01        5.68           3.60
# 4         4   23088  Not Specified      0.00      205.99           2.50
# ...     ...     ...            ...       ...         ...            ...
# 9421   9421   20275       Critical      0.06       35.89          14.72
# 9422   9422   20276       Critical      0.00        3.34           7.49
# 9423   9423   24491  Not Specified      0.08      550.98          45.70
# 9424   9424   25914           High      0.10      105.98          13.99
# 9425   9425   24492  Not Specified      0.09        7.78           2.50
#
#       Customer ID    Customer Name       Ship Mode Customer Segment  ...  \
# 0               2  Janice Fletcher     Regular Air        Corporate  ...
# 1               3    Bonnie Potter     Express Air        Corporate  ...
# 2               3    Bonnie Potter     Express Air        Corporate  ...
# 3               3    Bonnie Potter     Regular Air        Corporate  ...
# 4               3    Bonnie Potter     Express Air        Corporate  ...
# ...           ...              ...             ...              ...  ...
# 9421         3402   Frederick Cole     Regular Air         Consumer  ...
# 9422         3402   Frederick Cole     Regular Air         Consumer  ...
# 9423         3402   Frederick Cole  Delivery Truck         Consumer  ...
# 9424         3403    Tammy Buckley     Express Air         Consumer  ...
# 9425         3403    Tammy Buckley     Express Air         Consumer  ...
#
#        Region State or Province        City Postal Code  Order Date  \
# 0     Central          Illinois     Addison       60101  2012-05-28
# 1        West        Washington   Anacortes       98221  2010-07-07
# 2        West        Washington   Anacortes       98221  2011-07-27
# 3        West        Washington   Anacortes       98221  2011-07-27
# 4        West        Washington   Anacortes       98221  2011-07-27
# ...       ...               ...         ...         ...         ...
# 9421     East     West Virginia  Charleston       25314  2013-05-14
# 9422     East     West Virginia  Charleston       25314  2013-05-14
# 9423     East     West Virginia  Charleston       25314  2013-09-12
# 9424     West           Wyoming    Cheyenne       82001  2010-02-08
# 9425     West           Wyoming    Cheyenne       82001  2013-09-12
#
#       Ship Date       Profit Quantity ordered new    Sales Order ID
# 0    2012-05-30     1.320000                    2     5.90    88525
# 1    2010-07-08     4.560000                    4    13.01    88522
# 2    2011-07-28   -47.640000                    7    49.92    88523
# 3    2011-07-28   -30.510000                    7    41.64    88523
# 4    2011-07-27   998.202300                    8  1446.67    88523
# ...         ...          ...                  ...      ...      ...
# 9421 2013-05-15   137.860000                   13   447.87    87532
# 9422 2013-05-14   -39.070000                    3    13.23    87532
# 9423 2013-09-14 -1225.029097                    4  2215.93    87533
# 9424 2010-02-11   349.485000                    5   506.50    87530
# 9425 2013-09-14    78.062400                   23   172.48    87533
#
# [9426 rows x 25 columns]

# %%
Superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
#  15  State or Province     9426 non-null   object
#  16  City                  9426 non-null   object
#  17  Postal Code           9426 non-null   int64
#  18  Order Date            9426 non-null   datetime64[ns]
#  19  Ship Date             9426 non-null   datetime64[ns]
#  20  Profit                9426 non-null   float64
#  21  Quantity ordered new  9426 non-null   int64
#  22  Sales                 9426 non-null   float64
#  23  Order ID              9426 non-null   int64
# dtypes: datetime64[ns](2), float64(6), int64(5), object(11)
# memory usage: 1.7+ MB

# %%
Superstore.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
Superstore.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
#
#        Product Base Margin   Postal Code        Profit  Quantity ordered new  \
# count          9354.000000   9426.000000   9426.000000           9426.000000
# mean              0.512189  52446.327286    139.236410             13.798430
# std               0.135229  29374.597802    998.486483             15.107688
# min               0.350000   1001.000000 -16476.838000              1.000000
# 25%               0.380000  29406.000000    -74.017375              5.000000
# 50%               0.520000  52302.000000      2.567600             10.000000
# 75%               0.590000  78516.000000    140.243850             17.000000
# max               0.850000  99362.000000  16332.414000            170.000000
#
#                Sales      Order ID
# count    9426.000000   9426.000000
# mean      949.706272  82318.489073
# std      2598.019818  19149.448857
# min         1.320000      6.000000
# 25%        61.282500  86737.250000
# 50%       203.455000  88344.500000
# 75%       776.402500  89987.750000
# max    100119.160000  91591.000000

# %%
Superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
#  15  State or Province     9426 non-null   object
#  16  City                  9426 non-null   object
#  17  Postal Code           9426 non-null   int64
#  18  Order Date            9426 non-null   datetime64[ns]
#  19  Ship Date             9426 non-null   datetime64[ns]
#  20  Profit                9426 non-null   float64
#  21  Quantity ordered new  9426 non-null   int64
#  22  Sales                 9426 non-null   float64
#  23  Order ID              9426 non-null   int64
# dtypes: datetime64[ns](2), float64(6), int64(5), object(11)
# memory usage: 1.7+ MB

# %%
Superstore['Product Name'].value_counts()
# Out:
# Global High-Back Leather Tilter, Burgundy                            27
# Bevis 36 x 72 Conference Tables                                      26
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables    24
# Master Giant Foot® Doorstop, Safety Yellow                           24
# Wilson Jones Hanging View Binder, White, 1"                          23
#                                                                      ..
# Fellowes High-Stak® Drawer Files                                      1
# Computer Printout Index Tabs                                          1
# Hewlett Packard 610 Color Digital Copier / Printer                    1
# Global Comet™ Stacking Armless Chair                                  1
# Alliance Rubber Bands                                                 1
# Name: Product Name, Length: 1263, dtype: int64

# %%
# 3 . Find out how return that we ahve recived and with a product id 
order_return =pd.merge(Superstore , Superstore1)
check = order_return[['Order ID','Status']]

# %%
check
# Out:
#     Order ID    Status
# 0       9895  Returned
# 1      13959  Returned
# 2      13959  Returned
# 3      36038  Returned
# 4      39490  Returned
# ..       ...       ...
# 93      7107  Returned
# 94      7107  Returned
# 95     42823  Returned
# 96     13638  Returned
# 97     47109  Returned
#
# [98 rows x 2 columns]

# %%
check[(check['Status']=='Returned')]['Order ID'].count()
# 98 product are returned
# Out:
# 98

# %%
# 4 . try  to join order and return data both in sql and pandas 
order_return =pd.merge(Superstore , Superstore1)
order_return
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
#            Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0   Tony Wilkins Winters  Regular Air   Small Business  Office Supplies  ...
# 1            Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 2            Linda Weiss  Express Air      Home Office  Office Supplies  ...
# 3            Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 4          Eleanor Swain  Regular Air   Small Business  Office Supplies  ...
# ..                   ...          ...              ...              ...  ...
# 93         Gordon Brandt  Regular Air        Corporate  Office Supplies  ...
# 94         Gordon Brandt  Regular Air        Corporate  Office Supplies  ...
# 95         Gordon Brandt  Express Air        Corporate  Office Supplies  ...
# 96         Andrew Levine  Regular Air         Consumer       Technology  ...
# 97          Peter Brooks  Regular Air   Small Business        Furniture  ...
#
#    State or Province           City Postal Code  Order Date  Ship Date  \
# 0           New York  New York City       10012  2011-04-20 2011-04-24
# 1         Washington        Seattle       98103  2010-04-04 2010-04-06
# 2         Washington        Seattle       98103  2010-04-04 2010-04-06
# 3         Washington        Seattle       98103  2013-08-16 2013-08-18
# 4     North Carolina      Charlotte       28204  2013-08-12 2013-08-12
# ..               ...            ...         ...         ...        ...
# 93        California    Los Angeles       90061  2013-01-04 2013-01-06
# 94        California    Los Angeles       90061  2013-01-04 2013-01-05
# 95        California    Los Angeles       90061  2013-06-25 2013-06-27
# 96      Pennsylvania   Philadelphia       19112  2012-09-30 2012-10-02
# 97          New York  New York City       10112  2012-09-11 2012-09-13
#
#        Profit Quantity ordered new     Sales Order ID    Status
# 0     -6.8200                    9     54.79     9895  Returned
# 1    112.0600                   47    228.46    13959  Returned
# 2     16.7900                   19     77.61    13959  Returned
# 3    -89.0600                   52    190.52    36038  Returned
# 4    -81.9413                   76    912.06    39490  Returned
# ..        ...                  ...       ...      ...       ...
# 93   -33.9680                    3    113.14     7107  Returned
# 94   163.1200                   35   1886.52     7107  Returned
# 95   -22.5600                   12     73.71    42823  Returned
# 96   165.2000                   96   1337.67    13638  Returned
# 97  1844.9600                   92  12002.16    47109  Returned
#
# [98 rows x 25 columns]

# %%
# 5 . Try to find out how many unique customer that we have 
Superstore['Customer Name'].nunique()
#we have total 2703 customer_Id
# Out:
# 2703

# %%
# 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region 
Superstore2.count()
# There are 4 regions basically.
# Out:
# Region     4
# Manager    4
# dtype: int64

# %%
# 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
df =pd.DataFrame(Superstore['Ship Mode'].value_counts())
df
# Out:
#                 Ship Mode
# Regular Air          7036
# Delivery Truck       1283
# Express Air          1107

# %%
df1 = df.sum()
df1
# Out:
# Ship Mode    9426
# dtype: int64

# %%
df3 = ((df[['Ship Mode']])/df1)* 100
df3
# Out:
#                 Ship Mode
# Regular Air     74.644600
# Delivery Truck  13.611288
# Express Air     11.744112

# %%
# 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
Superstore.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
Superstore
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#        Region State or Province        City  Postal Code Order Date  \
# 0     Central          Illinois     Addison        60101 2012-05-28
# 1        West        Washington   Anacortes        98221 2010-07-07
# 2        West        Washington   Anacortes        98221 2011-07-27
# 3        West        Washington   Anacortes        98221 2011-07-27
# 4        West        Washington   Anacortes        98221 2011-07-27
# ...       ...               ...         ...          ...        ...
# 9421     East     West Virginia  Charleston        25314 2013-05-14
# 9422     East     West Virginia  Charleston        25314 2013-05-14
# 9423     East     West Virginia  Charleston        25314 2013-09-12
# 9424     West           Wyoming    Cheyenne        82001 2010-02-08
# 9425     West           Wyoming    Cheyenne        82001 2013-09-12
#
#       Ship Date       Profit  Quantity ordered new    Sales Order ID
# 0    2012-05-30     1.320000                     2     5.90    88525
# 1    2010-07-08     4.560000                     4    13.01    88522
# 2    2011-07-28   -47.640000                     7    49.92    88523
# 3    2011-07-28   -30.510000                     7    41.64    88523
# 4    2011-07-27   998.202300                     8  1446.67    88523
# ...         ...          ...                   ...      ...      ...
# 9421 2013-05-15   137.860000                    13   447.87    87532
# 9422 2013-05-14   -39.070000                     3    13.23    87532
# 9423 2013-09-14 -1225.029097                     4  2215.93    87533
# 9424 2010-02-11   349.485000                     5   506.50    87530
# 9425 2013-09-14    78.062400                    23   172.48    87533
#
# [9426 rows x 24 columns]

# %%
Superstore['Delivery_Time'] = Superstore['Ship Date'] - Superstore['Order Date']

# %%
Superstore
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#      State or Province        City Postal Code  Order Date  Ship Date  \
# 0             Illinois     Addison       60101  2012-05-28 2012-05-30
# 1           Washington   Anacortes       98221  2010-07-07 2010-07-08
# 2           Washington   Anacortes       98221  2011-07-27 2011-07-28
# 3           Washington   Anacortes       98221  2011-07-27 2011-07-28
# 4           Washington   Anacortes       98221  2011-07-27 2011-07-27
# ...                ...         ...         ...         ...        ...
# 9421     West Virginia  Charleston       25314  2013-05-14 2013-05-15
# 9422     West Virginia  Charleston       25314  2013-05-14 2013-05-14
# 9423     West Virginia  Charleston       25314  2013-09-12 2013-09-14
# 9424           Wyoming    Cheyenne       82001  2010-02-08 2010-02-11
# 9425           Wyoming    Cheyenne       82001  2013-09-12 2013-09-14
#
#            Profit Quantity ordered new    Sales Order ID Delivery_Time
# 0        1.320000                    2     5.90    88525        2 days
# 1        4.560000                    4    13.01    88522        1 days
# 2      -47.640000                    7    49.92    88523        1 days
# 3      -30.510000                    7    41.64    88523        1 days
# 4      998.202300                    8  1446.67    88523        0 days
# ...           ...                  ...      ...      ...           ...
# 9421   137.860000                   13   447.87    87532        1 days
# 9422   -39.070000                    3    13.23    87532        0 days
# 9423 -1225.029097                    4  2215.93    87533        2 days
# 9424   349.485000                    5   506.50    87530        3 days
# 9425    78.062400                   23   172.48    87533        2 days
#
# [9426 rows x 25 columns]

# %%
# 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days 
Superstore[Superstore['Delivery_Time'] > '10 days']
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# 5673   19005            Low      0.06       65.99           2.50         2088
# 5859   24392            Low      0.05       29.89           1.99         2143
# 5881   21257            Low      0.05        7.99           5.03         2153
# 8607   26351         Medium      0.00        8.32           2.38         3119
# 8609   26350         Medium      0.07      180.98          55.24         3119
# 8610   26352         Medium      0.06        4.20           2.26         3119
# 8973   20750            Low      0.06      125.99           8.08         3248
# 8982    2748            Low      0.03       11.97           5.81         3251
# 8983    2749            Low      0.08      195.99           4.20         3251
# 8993    2750            Low      0.06      125.99           8.08         3251
# 8996   20748            Low      0.03       11.97           5.81         3252
# 8997   20749            Low      0.08      195.99           4.20         3252
#
#                 Customer Name       Ship Mode Customer Segment  \
# 643   Brenda Nelson Blanchard     Regular Air        Corporate
# 1548               Dana Desai     Regular Air   Small Business
# 1549               Dana Desai     Express Air   Small Business
# 1678       Christopher Bryant  Delivery Truck         Consumer
# 1679       Christopher Bryant     Regular Air         Consumer
# 1680       Christopher Bryant     Regular Air         Consumer
# 1697               Neal Wolfe  Delivery Truck         Consumer
# 1698               Neal Wolfe     Regular Air         Consumer
# 1699               Neal Wolfe     Regular Air         Consumer
# 2515          Virginia Rivera     Regular Air      Home Office
# 5548          Ricky Dougherty     Regular Air         Consumer
# 5673             Carrie Boyle     Regular Air        Corporate
# 5859            Lester Sawyer     Regular Air      Home Office
# 5881               Anna Glenn     Regular Air      Home Office
# 8607              Jay Hubbard     Express Air        Corporate
# 8609              Jay Hubbard  Delivery Truck        Corporate
# 8610              Jay Hubbard     Regular Air        Corporate
# 8973            Earl Donnelly     Express Air        Corporate
# 8982             Peter Brooks     Regular Air        Corporate
# 8983             Peter Brooks     Regular Air        Corporate
# 8993             Peter Brooks     Express Air        Corporate
# 8996           Milton Harrell     Regular Air        Corporate
# 8997           Milton Harrell     Regular Air        Corporate
#
#      Product Category  ... State or Province           City Postal Code  \
# 643   Office Supplies  ...         Minnesota      Richfield       55423
# 1548       Technology  ...           Indiana    Bloomington       47401
# 1549  Office Supplies  ...           Indiana    Bloomington       47401
# 1678        Furniture  ...        California    Santa Clara       95051
# 1679  Office Supplies  ...        California    Santa Clara       95051
# 1680       Technology  ...        California    Santa Clara       95051
# 1697        Furniture  ...        Washington        Seattle       98119
# 1698  Office Supplies  ...        Washington        Seattle       98119
# 1699       Technology  ...        Washington        Seattle       98119
# 2515  Office Supplies  ...        California   Redwood City       94061
# 5548  Office Supplies  ...      South Dakota      Brookings       57006
# 5673       Technology  ...          New York   Mount Vernon       10550
# 5859       Technology  ...          Virginia        Fairfax       20151
# 5881       Technology  ...        California       Pasadena       91104
# 8607       Technology  ...           Florida        Orlando       32839
# 8609  Office Supplies  ...           Florida        Orlando       32839
# 8610  Office Supplies  ...           Florida        Orlando       32839
# 8973       Technology  ...         Louisiana        Slidell       70458
# 8982  Office Supplies  ...          New York  New York City       10112
# 8983       Technology  ...          New York  New York City       10112
# 8993       Technology  ...          New York  New York City       10112
# 8996  Office Supplies  ...          New York      Rotterdam       12306
# 8997       Technology  ...          New York      Rotterdam       12306
#
#       Order Date  Ship Date     Profit Quantity ordered new     Sales  \
# 643   2011-12-29 2012-03-22    58.5000                   19    204.67
# 1548  2011-12-30 2012-01-10   375.7050                    6    587.46
# 1549  2011-12-30 2012-01-14   -47.3950                   12     79.37
# 1678  2011-12-30 2012-01-16  -211.8850                   21   2699.94
# 1679  2011-12-30 2012-01-10   355.0119                   10    514.51
# 1680  2011-12-30 2012-01-27  1021.4001                   16   1480.29
# 1697  2011-12-30 2012-01-16  -423.7700                   83  10671.20
# 1698  2011-12-30 2012-01-10   469.6900                   41   2109.51
# 1699  2011-12-30 2012-01-27   727.3620                   65   6013.69
# 2515  2011-12-30 2012-03-31     5.8200                   10     22.35
# 5548  2011-12-30 2012-01-13    66.2250                   21    121.51
# 5673  2011-12-28 2012-01-14   187.4880                    8    451.34
# 5859  2011-12-26 2012-01-17  4230.2001                   12    344.16
# 5881  2011-12-26 2012-01-19   -23.4520                    2     15.56
# 8607  2011-12-29 2012-01-16 -1075.3960                   19    170.62
# 8609  2013-12-29 2014-01-15  -147.5180                   25   4529.95
# 8610  2013-12-29 2014-01-17  -689.8738                    2      9.64
# 8973  2011-12-26 2012-01-14     2.4780                   20   2180.31
# 8982  2011-12-26 2012-01-22   -31.7400                   31    388.52
# 8983  2011-12-26 2012-01-26  -557.9530                   13   2092.05
# 8993  2013-12-26 2014-01-14  1304.5590                   86   9375.35
# 8996  2011-12-26 2012-01-22   -15.8700                    8    100.26
# 8997  2011-12-26 2012-01-26  -278.9765                    3    482.78
#
#      Order ID Delivery_Time
# 643     87215       84 days
# 1548    86318       11 days
# 1549    86318       15 days
# 1678    87957       17 days
# 1679    87957       11 days
# 1680    87957       28 days
# 1697    19556       17 days
# 1698    19556       11 days
# 1699    19556       28 days
# 2515    86177       92 days
# 5548    88223       14 days
# 5673    88352       17 days
# 5859    87572       22 days
# 5881    91294       24 days
# 8607    86434       18 days
# 8609    86436       17 days
# 8610    86436       19 days
# 8973    87300       19 days
# 8982    19841       27 days
# 8983    19841       31 days
# 8993    19841       19 days
# 8996    87300       27 days
# 8997    87300       31 days
#
# [23 rows x 25 columns]

# %%
Superstore[Superstore['Delivery_Time'] > '10 days'].count()
# we have 23 order where its delivary time is more than 10 days
# Out:
# Row ID                  23
# Order Priority          23
# Discount                23
# Unit Price              23
# Shipping Cost           23
# Customer ID             23
# Customer Name           23
# Ship Mode               23
# Customer Segment        23
# Product Category        23
# Product Sub-Category    23
# Product Container       23
# Product Name            23
# Product Base Margin     23
# Region                  23
# State or Province       23
# City                    23
# Postal Code             23
# Order Date              23
# Ship Date               23
# Profit                  23
# Quantity ordered new    23
# Sales                   23
# Order ID                23
# Delivery_Time           23
# dtype: int64

# %%
# 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
Late_Delivary_manager = pd.merge(Superstore,Superstore2)
Late_Delivary_manager
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      24844         Medium      0.09       78.69          19.99           14
# 2      24846         Medium      0.08        3.28           2.31           14
# 3      24847         Medium      0.05        3.28           4.20           14
# 4      24848         Medium      0.05        3.58           1.63           14
# ...      ...            ...       ...         ...            ...          ...
# 9421   25689       Critical      0.10        4.98           4.70         3381
# 9422   26152  Not Specified      0.00       58.14          36.61         3382
# 9423   26153  Not Specified      0.00       29.99           5.50         3382
# 9424   26154  Not Specified      0.03       16.16           7.74         3382
# 9425   26140  Not Specified      0.04        5.98           7.15         3382
#
#                      Customer Name       Ship Mode Customer Segment  \
# 0                  Janice Fletcher     Regular Air        Corporate
# 1                Gwendolyn F Tyson     Regular Air   Small Business
# 2                Gwendolyn F Tyson     Regular Air   Small Business
# 3                Gwendolyn F Tyson     Regular Air   Small Business
# 4                Gwendolyn F Tyson     Regular Air   Small Business
# ...                            ...             ...              ...
# 9421  Christopher Norton Patterson     Regular Air      Home Office
# 9422                   Jon Beasley  Delivery Truck        Corporate
# 9423                   Jon Beasley     Regular Air        Corporate
# 9424                   Jon Beasley     Regular Air        Corporate
# 9425                   Jon Beasley     Regular Air        Corporate
#
#      Product Category  ...        City Postal Code Order Date  Ship Date  \
# 0     Office Supplies  ...     Addison       60101 2012-05-28 2012-05-30
# 1           Furniture  ...  Prior Lake       55372 2010-05-12 2010-05-14
# 2     Office Supplies  ...  Prior Lake       55372 2010-05-12 2010-05-13
# 3     Office Supplies  ...  Prior Lake       55372 2010-05-12 2010-05-13
# 4     Office Supplies  ...  Prior Lake       55372 2010-05-12 2010-05-13
# ...               ...  ...         ...         ...        ...        ...
# 9421  Office Supplies  ...       Macon       31204 2013-10-09 2013-10-11
# 9422        Furniture  ...    Marietta       30062 2011-05-21 2011-05-21
# 9423       Technology  ...    Marietta       30062 2011-05-21 2011-05-22
# 9424        Furniture  ...    Marietta       30062 2011-05-21 2011-05-23
# 9425  Office Supplies  ...    Marietta       30062 2013-10-07 2013-10-09
#
#           Profit Quantity ordered new    Sales  Order ID Delivery_Time Manager
# 0        1.32000                    2     5.90     88525        2 days   Chris
# 1      803.47050                   16  1164.45     86838        2 days   Chris
# 2      -24.03000                    7    22.23     86838        1 days   Chris
# 3      -37.03000                    4    13.99     86838        1 days   Chris
# 4       -0.71000                    4    14.26     86838        1 days   Chris
# ...          ...                  ...      ...       ...           ...     ...
# 9421   174.38400                   15    69.66     88850        2 days     Sam
# 9422    12.42600                   13   807.21     88842        0 days     Sam
# 9423   -94.55600                    7   218.15     88842        1 days     Sam
# 9424 -5257.04634                    1    20.17     88842        2 days     Sam
# 9425   -85.90400                    3    21.86     88849        2 days     Sam
#
# [9426 rows x 26 columns]

# %%
df5 = pd.DataFrame(Late_Delivary_manager[Late_Delivary_manager['Delivery_Time'] > "15 days"]['Manager'])
df5
# Out:
#       Manager
# 189     Chris
# 3476  William
# 3478  William
# 3495  William
# 3497  William
# 3826  William
# 4476  William
# 6638     Erin
# 7314     Erin
# 7315     Erin
# 7325     Erin
# 7328     Erin
# 7329     Erin
# 8435      Sam
# 9184      Sam
# 9186      Sam
# 9187      Sam
# 9307      Sam

# %%
df6 = pd.DataFrame(Late_Delivary_manager[Late_Delivary_manager['Delivery_Time'] > "15 days"]['Manager']).count()
df6
# There are 18 data which takes more than 15 days to deliver it.
# Out:
# Manager    18
# dtype: int64

# %%
Superstore
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#      State or Province        City Postal Code  Order Date  Ship Date  \
# 0             Illinois     Addison       60101  2012-05-28 2012-05-30
# 1           Washington   Anacortes       98221  2010-07-07 2010-07-08
# 2           Washington   Anacortes       98221  2011-07-27 2011-07-28
# 3           Washington   Anacortes       98221  2011-07-27 2011-07-28
# 4           Washington   Anacortes       98221  2011-07-27 2011-07-27
# ...                ...         ...         ...         ...        ...
# 9421     West Virginia  Charleston       25314  2013-05-14 2013-05-15
# 9422     West Virginia  Charleston       25314  2013-05-14 2013-05-14
# 9423     West Virginia  Charleston       25314  2013-09-12 2013-09-14
# 9424           Wyoming    Cheyenne       82001  2010-02-08 2010-02-11
# 9425           Wyoming    Cheyenne       82001  2013-09-12 2013-09-14
#
#            Profit Quantity ordered new    Sales Order ID Delivery_Time
# 0        1.320000                    2     5.90    88525        2 days
# 1        4.560000                    4    13.01    88522        1 days
# 2      -47.640000                    7    49.92    88523        1 days
# 3      -30.510000                    7    41.64    88523        1 days
# 4      998.202300                    8  1446.67    88523        0 days
# ...           ...                  ...      ...      ...           ...
# 9421   137.860000                   13   447.87    87532        1 days
# 9422   -39.070000                    3    13.23    87532        0 days
# 9423 -1225.029097                    4  2215.93    87533        2 days
# 9424   349.485000                    5   506.50    87530        3 days
# 9425    78.062400                   23   172.48    87533        2 days
#
# [9426 rows x 25 columns]

# %%
# 11 . Gorup by region and find out which region is more profitable 
Superstore.groupby('Region')['Profit'].sum()

# Central Region has more profit
# Out:
# Region
# Central    519825.567067
# East       377566.186045
# South      104201.192420
# West       310849.453897
# Name: Profit, dtype: float64

# %%
# 12 . Try to find out overalll in which country we are giving more discount 
df7 = pd.DataFrame(Superstore.groupby('City')['Discount'].sum())
df7
# Out:
#             Discount
# City
# Aberdeen        0.32
# Abilene         0.22
# Abington        0.08
# Acton           0.00
# Addison         0.23
# ...              ...
# York            0.21
# Youngstown      0.33
# Yuba City       0.01
# Yucaipa         0.15
# Yuma            0.18
#
# [1424 rows x 1 columns]

# %%
df7['Rank'] = df7['Discount'].rank(method = 'max', ascending = False)

# %%
df7[df7['Rank']== 1]
# Los Angeles getting more discount
# Out:
#              Discount  Rank
# City
# Los Angeles     10.37   1.0

# %%
# 13 . Give me a list of unique postal code 
df8 = (Superstore['Postal Code'].unique())
df8
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %%
Superstore.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Delivery_Time'],
#       dtype='object')

# %%
# 14 . which customer segement is more profitalble find it out . 
df9 = pd.DataFrame(Superstore.groupby('Customer Segment')['Profit'].sum())
df9
# Out:
#                          Profit
# Customer Segment
# Consumer          206559.625348
# Corporate         505538.627783
# Home Office       283869.553814
# Small Business    316474.592482

# %%
df9['Rank'] = df9['Profit'].rank(method= 'max',ascending = False)

# %%
df9[df9['Rank'] == 1]
# Corporate is more profiatable
# Out:
#                          Profit  Rank
# Customer Segment
# Corporate         505538.627783   1.0

# %%
# 15 . try to find out the 10th most loss making product catagory .
df10 =pd.DataFrame(Superstore.groupby('Product Name')['Profit'].sum())
df10
# Out:
#                                                          Profit
# Product Name
# "While you Were Out" Message Book, One Form per...   708.820800
# #10 Self-Seal White Envelopes                        223.197520
# #10 White Business Envelopes,4 1/8 x 9 1/2          1164.001460
# #10- 4 1/8" x 9 1/2" Recycled Envelopes             -888.757800
# #10- 4 1/8" x 9 1/2" Security-Tint Envelopes       -1288.400800
# ...                                                         ...
# i500plus                                             808.244640
# i600                                                -525.934816
# iDEN i550                                           2624.076000
# iDEN i95                                            -371.274704
# iDENi80s                                            -471.229440
#
# [1263 rows x 1 columns]

# %%
df10['Rank'] = df10['Profit'].rank(method = 'max')

# %%
df10[df10['Rank'] == 10]
# Out:
#                                                        Profit  Rank
# Product Name
# Eldon ClusterMat Chair Mat with Cordless Antist... -9543.6525  10.0

# %%
#16. Try to find out 10 top  product with highest margins 
Superstore.sort_values(['Product Base Margin'])['Product Name'].head(10)
# Out:
# 2431              GBC DocuBind 200 Manual Binding Machine
# 8248       Peel & Seel® Recycled Catalog Envelopes, Brown
# 1515       Peel & Seel® Recycled Catalog Envelopes, Brown
# 5050       Peel & Seel® Recycled Catalog Envelopes, Brown
# 413                                           Accessory31
# 5034                          Prang Dustless Chalk Sticks
# 8308         Staples Brown Kraft Recycled Clasp Envelopes
# 8311     Storex DuraTech Recycled Plastic Frosted Binders
# 8318                                          Accessory31
# 1553    Adams Telephone Message Book w/Frequently-Call...
# Name: Product Name, dtype: object
